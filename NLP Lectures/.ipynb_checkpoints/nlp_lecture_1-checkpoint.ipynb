# %% [markdown]
# # Lowercase

# %%
text = 'Hello WorLD!'
lowercased_text = text.lower()

print(lowercased_text)
# Out:
# hello world!

# %% [markdown]
# # Punctuation and Special Character

# %%
import re

# %%
text = "Hello, world! This is?* 💓an&/|~^+%\ example- of text preprocessing"

punctuation_pattern = r'[^\w\s]'

text_cleaned = re.sub(punctuation_pattern, '', text)

print(text_cleaned)
# Out:
# Hello world This is an example of text preprocessing

# %% [markdown]
# # Stop Words

# %% [markdown]
# # Stop words are that do not contribute to the meaning of sentence

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install stopwords
# Out:
# Requirement already satisfied: stopwords in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\M.Aheed
# [nltk_data]     Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
print(stopwords.words("english"))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
def remove_stopwords(text, language):
    text = text.lower()
    stop_words = set(stopwords.words(language))
    word_tokens = text.split()
    filtered_text = [word for word in word_tokens if word not in stop_words]
    print(language)
    print(filtered_text)

# %%
en_text = "This is a sample sentence and we are going to remove the stopwords from this"
remove_stopwords(en_text, "english")
# Out:
# english
# ['sample', 'sentence', 'going', 'remove', 'stopwords']

# %% [markdown]
# # URLs
