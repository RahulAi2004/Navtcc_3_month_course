# %%
import nltk

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\M.Aheed
# [nltk_data]     Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import TweetTokenizer

# %%
tweet_tokenizer = TweetTokenizer()
sample_text = "This is a tweet @jack #NLP"
tokens = tweet_tokenizer.tokenize(sample_text)
print(sample_text)
print(tokens)
# Out:
# This is a tweet @jack #NLP
# ['This', 'is', 'a', 'tweet', '@jack', '#NLP']

# %%
from nltk.tokenize import sent_tokenize

# %%
sample_text = "this is a sentence. This is another one!\nAnd this is the"
sentences = sent_tokenize(sample_text)
print(sample_text)
print(sentences)
# Out:
# this is a sentence. This is another one!
# And this is the
# ['this is a sentence.', 'This is another one!', 'And this is the']

# %%
from nltk.corpus import stopwords

stopwords_ = set(stopwords.words("english"))

# %%
sample_text = "this is a sample text"
tokens = sample_text.split()
clean_tokens = [t for t in tokens if not t in stopwords_]
clean_text = " ".join(clean_tokens)
print(clean_tokens)
print(clean_text)
# Out:
# ['sample', 'text']
# sample text

# %% [markdown]
# # Porterstemmer

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
words = ['running', "flies", "happily", "better", "jumps", "happiest"]

# %%
stemmed_words = [stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['run', 'fli', 'happili', 'better', 'jump', 'happiest']

# %% [markdown]
# # Lancaster Stemmer

# %%
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()

# %%
stemmed_words = [stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['run', 'fli', 'happy', 'bet', 'jump', 'happiest']

# %% [markdown]
# # Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
stemmed_words = [stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['run', 'fli', 'happili', 'better', 'jump', 'happiest']

# %% [markdown]
# # RegExp Stemmer

# %%
from nltk.stem import RegexpStemmer
stemmer = RegexpStemmer("ing$|es$|ly$|er$", min=4)

# %%
stemmed_words = [stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['runn', 'fli', 'happi', 'bett', 'jumps', 'happiest']

# %% [markdown]
# # WordNet Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer
nltk.download("wordnet")
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\M.Aheed
# [nltk_data]     Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
print(lemmatized_words)
# Out:
# ['running', 'fly', 'happily', 'better', 'jump', 'happiest']

# %% [markdown]
# # TextBlob Lemmatizer

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (0.20.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk>=3.9->textblob) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import Word

# %%
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
print(lemmatized_words)
# Out:
# ['running', 'fly', 'happily', 'better', 'jump', 'happiest']

# %% [markdown]
# # Part of Speech Tagging

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\M.Aheed
# [nltk_data]     Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\M.Aheed Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package tagsets_json to C:\Users\M.Aheed
# [nltk_data]     Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!
# True

# %%
sentence = "the quick brown fox jumpy over the lazy dog"
words = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(words)

print("")
print("POS Tags\n", pos_tags, "\n")

for (word, tag) in pos_tags:
    print(nltk.help.upenn_tagset(tagpattern=tag))
# Out:
# POS Tags
#  [('the', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumpy', 'NN'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN')]
#
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# None
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# None
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# None
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# None
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# None
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# None
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# None
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# None
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# None

# %% [markdown]
# # Chunking

# %%
pip install svgling
# Out:
# Requirement already satisfied: svgling in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (0.5.0)
# Requirement already satisfied: svgwrite in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from svgling) (1.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.download('punk_tab')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Error loading punk_tab: Package 'punk_tab' not found in
# [nltk_data]     index
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\M.Aheed
# [nltk_data]     Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\M.Aheed
# [nltk_data]     Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\M.Aheed Siddiqui\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
from nltk.tree import Tree

# %%
sentence = "The big brown dog barked loudly."
words = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(words)

chunked = nltk.ne_chunk(pos_tags)

reg_exp = "NP: {<DT>?<JJ>*<NN>*}"
rp = nltk.RegexpParser(reg_exp)
result = rp.parse(chunked)

result
# Out:
# Tree('S', [Tree('NP', [('The', 'DT'), ('big', 'JJ'), ('brown', 'NN'), ('dog', 'NN')]), ('barked', 'VBD'), ('loudly', 'RB'), ('.', '.')])
